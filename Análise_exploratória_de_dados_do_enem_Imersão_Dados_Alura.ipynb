# %% [markdown]
# <a href="https://colab.research.google.com/github/amnacas/DadosEnem2019/blob/main/An%C3%A1lise_explorat%C3%B3ria_de_dados_do_enem_Imers%C3%A3o_Dados_Alura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![enem-2019.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **Análise de dados do Enem 2019** *por Amanda Nacas*

# %% [markdown]
# > Criado em 1998, o Exame Nacional do Ensino Médio (Enem) tem o objetivo de avaliar o desempenho do estudante ao fim da escolaridade básica. Podem participar do exame alunos que estão concluindo ou que já concluíram o ensino médio em anos anteriores. [Portal MEC](<http://portal.mec.gov.br/enem-sp-2094708791>)
#
#
#
# > O Enem é utilizado como critério de seleção para os estudantes que pretendem concorrer a uma bolsa no Programa Universidade para Todos (ProUni). Além disso, cerca de 500 universidades já usam o resultado do exame como critério de seleção para o ingresso no ensino superior, seja complementando ou substituindo o vestibular. [Portal MEC](<http://portal.mec.gov.br/enem-sp-2094708791>)

# %% [markdown]
# ## **Motivação**

# %% [markdown]
# Esse projeto foi desenvolvido durante a semana Imersão Dados da [Alura](http://www.alura.com.br) que ocorreu em outubro de 2020.
#
# Todo ano milhares de pessoas prestam o exame nacional do ensino médio (ENEM), seja como treineiro ou oficialmente.
#
# O enem deixou de ser apenas uma avaliação do desempenho do estudante ao fim do ensino médio e passou a ser utilizado como criterio de seleção para concorrer a vagas em diversas universidade e tambem para obtenção de bolsas integrais e parciais do Programa Unversidade para todos (ProUni).
#
# Ao se inscrever no Enem a pessoa preenche um formulário socioeconômico que tem como objetivo de traçar o perfil desses estudantes e com isso aperfeiçoar a politica educacional do ministerio da educação. Esses dados são armazenados de forma anônima juntamente com os resultados da provas e podem ser encontrados no site do [INEP](<http://inep.gov.br/microdados>).

# %% [markdown]
# ## **Dados**

# %% [markdown]
# Os dados aqui utilizados correspondem ao ano de 2019, no entanto, inicialmente para facilitar o processamento dos dados iremos utilizar apenas uma fração desses dados do INEP que foi compliado e disponibilizado durante a Semana de Imersão de Dados da Alura.
#
# Dessa forma, o dataset utilizado pode ser encontrado [neste link](https://github.com/alura-cursos/imersao-dados-2-2020/blob/master/MICRODADOS_ENEM_2019_SAMPLE_43278.csv?raw=true).

# %% [markdown]
# ## **Objetivos**

# %% [markdown]
# Utilizando esses dados socioeconômicos disponibilizados pelo INEP e os resultados das provas realizadas no ano de 2019 será realizada uma análise da influência dos fatores citados abaixo nos resultados das provas do enem e com isso gerar uma reflexão a respeito dos resultados obtidos.
#
# Fatores que serão analisados:
#
# * Cor/Raça
# * Escola pública ou particular
# * Treineiro
# * Deficiencias ou condição especiais
# * Renda familiar (Q006)
# * Mobilidade
#   * Carro na residência (Q010)
#   * Moto na Residencia (Q011)
# * Acesso a internet (Q025)
# * Acesso a computador (Q024)
#
#
# **Questionamentos**:
#
# 1. Quais são os estados com maior número de participantes (treineiros ou não)? Está associado com o tamanho da população do estado?
#
# 2. Faixa de idade de quem realizou a prova do enem em 2019.
#
# 3. Distribuição de alunos por estado, genêro, cor/raça e escola publica ou particular.
#
# 4. Impacto da distribuição da Renda familiar no desempenho dos alunos.
#
# 5. A mobilidade pode ser um fator que influência na evasão das provas?
#
# 6. Qual a porcentagem de alunos com deficiencias ou condições especiais? Qual o desempenho e o indice de evasão nas provas?
#
# 7. Qual é o impacto da ausência de computador e internet no desempenho dos alunos?
#
# 8. Existe alguma correlação entre as notas das provas? POr exemplo, quem vai bem em Ciências Naturais vai bem em Matemática?

# %% [markdown]
# ## **Dicionário de Variáveis**

# %% [markdown]
# O arquivo .csv importado possui 136 colunas, correspondentes as variáveis.
# O INEP disponibiliza um dicionário das variáveis utilizadas descrevendo cada uma delas de forma detalhada.
#
# Para facilitar a compreenção dos dados estudados você pode baixar o dicionário de variáveis [clicando aqui](https://github.com/amnacas/DadosEnem2019/blob/main/Dicion%C3%A1rio_Microdados_Enem_2019.xlsx).

# %% [markdown]
# ## **Bibliotecas utilizadas**

# %%
# Importando as bibliotecas necessárias 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %matplotlib inline sets the backend of matplotlib to the 'inline' backend.
# With this backend, the output of plotting commands is displayed inline within
# frontends like the Jupyter notebook, directly below the code cell that produced it.
# The resulting plots will then also be stored in the notebook document

# %% [markdown]
# ## **Importando o Dataframe**

# %%
# Importando os dados do enem 2019 para um dataframe
df = pd.read_csv("https://raw.githubusercontent.com/alura-cursos/imersao-dados-2-2020/master/MICRODADOS_ENEM_2019_SAMPLE_43278.csv")

# %% [markdown]
# ## **Análise dos dados**

# %% [markdown]
# Primeiramente iremos dar uma olhada nas primeiras 5 entradas do nosso conjunto de dados, verificar o número de linhas e colunas e quais são as colunas desse conjuto de dados.

# %%
df.head()
# Out:
#    NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q023  Q024 Q025
# 0  190001004661    2019                  1506138  ...    A     B    B
# 1  190001004674    2019                  1504208  ...    A     A    B
# 2  190001004722    2019                  1501402  ...    A     A    B
# 3  190001004735    2019                  1507300  ...    A     A    B
# 4  190001004776    2019                  1500800  ...    A     A    B
#
# [5 rows x 136 columns]

# %%
print (f"Número de linhas e colunas:", df.shape)
# Out:
# Número de linhas e colunas: (127380, 136)

# %%
print (f"Colunas do dataset:\n", df.columns.values)
# Out:
# Colunas do dataset:
#  ['NU_INSCRICAO' 'NU_ANO' 'CO_MUNICIPIO_RESIDENCIA'
#  'NO_MUNICIPIO_RESIDENCIA' 'CO_UF_RESIDENCIA' 'SG_UF_RESIDENCIA'
#  'NU_IDADE' 'TP_SEXO' 'TP_ESTADO_CIVIL' 'TP_COR_RACA' 'TP_NACIONALIDADE'
#  'CO_MUNICIPIO_NASCIMENTO' 'NO_MUNICIPIO_NASCIMENTO' 'CO_UF_NASCIMENTO'
#  'SG_UF_NASCIMENTO' 'TP_ST_CONCLUSAO' 'TP_ANO_CONCLUIU' 'TP_ESCOLA'
#  'TP_ENSINO' 'IN_TREINEIRO' 'CO_ESCOLA' 'CO_MUNICIPIO_ESC'
#  'NO_MUNICIPIO_ESC' 'CO_UF_ESC' 'SG_UF_ESC' 'TP_DEPENDENCIA_ADM_ESC'
#  'TP_LOCALIZACAO_ESC' 'TP_SIT_FUNC_ESC' 'IN_BAIXA_VISAO' 'IN_CEGUEIRA'
#  'IN_SURDEZ' 'IN_DEFICIENCIA_AUDITIVA' 'IN_SURDO_CEGUEIRA'
#  'IN_DEFICIENCIA_FISICA' 'IN_DEFICIENCIA_MENTAL' 'IN_DEFICIT_ATENCAO'
#  'IN_DISLEXIA' 'IN_DISCALCULIA' 'IN_AUTISMO' 'IN_VISAO_MONOCULAR'
#  'IN_OUTRA_DEF' 'IN_GESTANTE' 'IN_LACTANTE' 'IN_IDOSO'
#  'IN_ESTUDA_CLASSE_HOSPITALAR' 'IN_SEM_RECURSO' 'IN_BRAILLE'
#  'IN_AMPLIADA_24' 'IN_AMPLIADA_18' 'IN_LEDOR' 'IN_ACESSO' 'IN_TRANSCRICAO'
# ...

# %% [markdown]
# ### 1. Quais são os estados com maior número de participantes (treineiros ou não)? Está associado com o tamanho da população do estado?

# %%
print(f" Estados onde foi realizado o Enem 2019:\n", df["SG_UF_RESIDENCIA"].unique())
print(f"\n Número de alunos em cada estado:\n", df["SG_UF_RESIDENCIA"].value_counts())
# Out:
#  Estados onde foi realizado o Enem 2019:
#  ['PA' 'RO' 'MT' 'AC' 'AM' 'RR' 'MA' 'PR' 'BA' 'PI' 'CE' 'PE' 'AP' 'TO'
#  'SC' 'GO' 'MG' 'SP' 'SE' 'RJ' 'PB' 'AL' 'RN' 'ES' 'DF' 'RS' 'MS']
#
#  Número de alunos em cada estado:
#  SP    20264
# MG    13547
# BA    10040
# RJ     8467
# CE     7381
# PA     7170
# PE     6941
# MA     5543
# RS     5466
# PR     5259
# GO     4268
# PB     3690
# PI     3034
# RN     2959
# AM     2820
# SC     2673
# ES     2550
# DF     2408
# AL     2263
# MT     2230
# SE     1815
# MS     1655
# RO     1400
# TO     1178
# AP     1047
# AC      946
# RR      366
# Name: SG_UF_RESIDENCIA, dtype: int64

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1)
sns.histplot(df, x = "SG_UF_RESIDENCIA", hue="IN_TREINEIRO", stat="probability" )
plt.title("Porcentagem de alunos e treineiros por Estado no Enem 2019", fontsize=14)
plt.xlabel("Estado")
plt.show();

# %% [markdown]
# ### 2. Faixa de idade de quem realizou a prova do enem em 2019.

# %%
df["NU_IDADE"].value_counts().sort_index()
# Out:
# 13        4
# 14      141
# 15     2009
# 16     7830
# 17    21256
#       ...
# 73        2
# 75        2
# 76        1
# 77        1
# 82        1
# Name: NU_IDADE, Length: 65, dtype: int64

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1)
sns.histplot(df, x = "NU_IDADE", hue="TP_SEXO", stat="probability",bins=20)
plt.title("Distribuição da idade e gênero no Enem 2019", fontsize=14)
plt.xlabel("Idade")
plt.show();

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1)
sns.histplot(df, x = "NU_IDADE", hue="IN_TREINEIRO", stat="probability",bins=25)
plt.title("Distribuição da idade dos alunos e treineiros no Enem 2019", fontsize=14)
plt.xlabel("Idade")
plt.show();

# %% [markdown]
# ### 3. Distribuição de alunos por estado, genêro, cor/raça e escola publica ou particular.

# %% [markdown]
# ### 4. Impacto da distribuição da Renda familiar no desempenho dos alunos.

# %% [markdown]
# ### 5. A mobilidade pode ser um fator que influência na evasão das provas?

# %% [markdown]
# ### 6. Qual a porcentagem de alunos com deficiencias ou condições especiais? Qual o desempenho e o indice de evasão nas provas?

# %% [markdown]
# ### 7. Qual é o impacto da ausência de computador e internet no desempenho dos alunos?

# %% [markdown]
# ### 8. Existe alguma correlação entre as notas das provas? POr exemplo, quem vai bem em Ciências Naturais vai bem em Matemática?

# %%
provas = ["NU_NOTA_CN","NU_NOTA_CH","NU_NOTA_MT","NU_NOTA_LC","NU_NOTA_REDACAO"]
df[provas].describe()
# Out:
#          NU_NOTA_CN    NU_NOTA_CH    NU_NOTA_MT    NU_NOTA_LC  NU_NOTA_REDACAO
# count  92758.000000  98043.000000  92758.000000  98043.000000     98043.000000
# mean     477.964015    507.365912    523.555206    520.463928       571.570025
# std       76.296099     82.972839    109.416939     64.556578       188.076455
# min        0.000000      0.000000      0.000000      0.000000         0.000000
# 25%      418.000000    447.900000    435.300000    483.700000       480.000000
# 50%      470.200000    510.900000    501.600000    526.100000       580.000000
# 75%      533.300000    567.100000    598.200000    565.100000       680.000000
# max      797.300000    809.400000    985.000000    801.700000      1000.000000

# %%
df["NU_NOTA_TOTAL"] = df[provas].sum(axis=1)
df.head()
# Out:
#    NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q024  Q025 NU_NOTA_TOTAL
# 0  190001004661    2019                  1506138  ...    B     B        2288.9
# 1  190001004674    2019                  1504208  ...    A     B        1184.6
# 2  190001004722    2019                  1501402  ...    A     B        2350.5
# 3  190001004735    2019                  1507300  ...    A     B        2555.7
# 4  190001004776    2019                  1500800  ...    A     B        2803.5
#
# [5 rows x 137 columns]

# %%
provas.append("NU_NOTA_TOTAL")
df[provas].query("NU_NOTA_TOTAL == 0")
# Out:
#         NU_NOTA_CN  NU_NOTA_CH  ...  NU_NOTA_REDACAO  NU_NOTA_TOTAL
# 10             NaN         NaN  ...              NaN            0.0
# 11             NaN         NaN  ...              NaN            0.0
# 26             NaN         NaN  ...              NaN            0.0
# 38             NaN         NaN  ...              NaN            0.0
# 40             NaN         NaN  ...              NaN            0.0
# ...            ...         ...  ...              ...            ...
# 127351         NaN         NaN  ...              NaN            0.0
# 127365         NaN         NaN  ...              NaN            0.0
# 127366         NaN         NaN  ...              NaN            0.0
# 127368         NaN         NaN  ...              NaN            0.0
# 127374         NaN         NaN  ...              NaN            0.0
#
# [29162 rows x 6 columns]

# %%
dados_sem_notas_zero = df.query("NU_NOTA_TOTAL != 0")
dados_sem_notas_zero.head()
# Out:
#    NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q024  Q025 NU_NOTA_TOTAL
# 0  190001004661    2019                  1506138  ...    B     B        2288.9
# 1  190001004674    2019                  1504208  ...    A     B        1184.6
# 2  190001004722    2019                  1501402  ...    A     B        2350.5
# 3  190001004735    2019                  1507300  ...    A     B        2555.7
# 4  190001004776    2019                  1500800  ...    A     B        2803.5
#
# [5 rows x 137 columns]

# %%
plt.figure(figsize=(12,8))
sns.histplot(dados_sem_notas_zero, x = "NU_NOTA_TOTAL")

# %%
plt.figure(figsize=(12,8))
sns.histplot(dados_sem_notas_zero, x = "NU_NOTA_MT")

# %%
plt.figure(figsize=(12,8))
sns.histplot(dados_sem_notas_zero, x = "NU_NOTA_LC")

# %%
plt.figure(figsize=(12,8))
sns.histplot(dados_sem_notas_zero, x = "NU_NOTA_CH")

# %%
plt.figure(figsize=(12,8))
sns.histplot(dados_sem_notas_zero, x = "NU_NOTA_CN")

# %%
plt.figure(figsize=(12,8))
sns.histplot(dados_sem_notas_zero, x = "NU_NOTA_REDACAO")

# %%
provas
# Out:
# ['NU_NOTA_CN',
#  'NU_NOTA_CH',
#  'NU_NOTA_MT',
#  'NU_NOTA_LC',
#  'NU_NOTA_REDACAO',
#  'NU_NOTA_TOTAL']

# %%
sns.pairplot(dados_sem_notas_zero[provas])

# %%
correlacao = dados_sem_notas_zero[provas].corr()
correlacao
# Out:
#                  NU_NOTA_CN  NU_NOTA_CH  ...  NU_NOTA_REDACAO  NU_NOTA_TOTAL
# NU_NOTA_CN         1.000000    0.668979  ...         0.504740       0.785600
# NU_NOTA_CH         0.668979    1.000000  ...         0.528338       0.735534
# NU_NOTA_MT         0.649527    0.610332  ...         0.493046       0.790051
# NU_NOTA_LC         0.641624    0.744170  ...         0.535797       0.711686
# NU_NOTA_REDACAO    0.504740    0.528338  ...         1.000000       0.783647
# NU_NOTA_TOTAL      0.785600    0.735534  ...         0.783647       1.000000
#
# [6 rows x 6 columns]

# %%
sns.heatmap(correlacao, cmap="Blues", center=0, annot=True)

# %% [markdown]
# # **Conclusões**

# %% [markdown]
# # **Referência Bibliográfica**
